# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Mon Aug  9 22:40:33 2021

@author: carolyndavis
"""

# =============================================================================
# For each of the following questions, formulate a null and alternative hypothesis 
# (be as specific as you can be), then give an example of what a true positive, 
# true negative, type I and type II errors would look like. Note that some of the 
# questions are intentionally phrased in a vague way. It is your job to reword these 
# as more precise questions that could be tested.
# =============================================================================

# =============================================================================
# # Has the network latency gone up since we switched internet service providers?
# =============================================================================

#Null Hyp: "There is no evident correlation between internet service provider and network latency for users.
#Alt Hyp: "Choice of network provider has a distinct correlation to network latency for users.

#True Positive: User choice of internet service provider actually does positivly correlate to network latency

#True Negative: There actually is no correlation between internet service provider and network latency.
    
#Type I: Result indicate internet service provider does have an effect on network latency, when in fact it actually doesn't differ 
            #at all among internet service providers
    
#Type II: Results indicate choice of internet service provider does not effect network latency, when actually network latency is 
            #differing among internet service providers


# =============================================================================
# # Is the website redesign any good?
# =============================================================================
#Null Hyp: "A redesign of the company website has no effect on the website acceptance ratings among users"
#Alt Hyp: "The redesign of the company website improved overall acceptance ratings among users"

#True Positive: Redesigning the website results in increase of website acceptance ratings

#True Negative: Redesigning the website had no effect on user acceptance rating.
    
#Type I: Results indicated redesign of website does have and effect user acceptance ratings, but actually it has had no effect on acceptance ratings among users.
    
#Type II: Results indicated redesign of website does not have an effect user acceptance ratings, but actually it has significantly increased the acceptance rating among users. 

# =============================================================================
# # Is our television ad driving more sales?
# =============================================================================

#Null Hyp: "The television product ad does not effect the product's overall rate of sales."
#Alt Hyp: "The television product ad resulted in a significant increase in the rate of sales for the product."


#True Positive: The tv product ad has had a significant impact on sales, increasing them significantly.

#True Negative: The tv product ad has had no effect on sales for the product.
    
#Type I: The tv product ad resulted in a significant increase in sales, but in reality it has had no effect worth reporting.
    
#Type II: The tv product ad resulted in no apparent correlation to an increase in product sales, but it has actually doubled product sales in the last month alone.
